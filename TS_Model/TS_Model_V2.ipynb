# %%
import os
import sys

import pandas as pd
import numpy as np

import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
import statsmodels.stats as sms
from arch import arch_model

import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline 可以在Ipython编译器里直接使用，功能是可以内嵌绘图，并且可以省略掉plt.show()这一步。
# %matplotlib inline

# %%
# 读取数据
data = pd.read_csv("price_data.csv",index_col  = 0)


buy_list = []

correct_count = 0
total_count = 0
for i in range(1,3):
    print "开始计算第%d天"%int(i)
    for col in data.columns:
        lrets = data[col].pct_change().dropna()

        TS = lrets[-i-250:-i]

        p_ = 3
        o_ = 0
        q_ = 2

        # Using student T distribution usually provides better fit
        am = arch_model(TS, p=p_, o=o_, q=q_, dist='StudentsT')
        res = am.fit(update_freq=5, disp='off')

        out = res.forecast(horizon=1, start=None, align='origin')


        if  float(out.mean['h.1'][-1]) - 2.5* float(out.variance['h.1'][-1])>0:
            total_count += 1
            buy_list.append(col)

            if lrets[-i] > 0:
                correct_count += 1
            
#     print "股票：%s，预测均值为：%f，方差为：%f，5%置信区间为%f"%(str(col),float(out.mean['h.1'].iloc[-1,:]),float(out.variance['h.1'].iloc[-1,:]),float(out.mean['h.1'].iloc[-1,:])-1.96*float(out.variance['h.1'].iloc[-1,:]))
# Out:
# 开始计算第1天
# c:\python27\lib\site-packages\arch\univariate\base.py:524: ConvergenceWarning:
# The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# c:\python27\lib\site-packages\arch\univariate\base.py:524: ConvergenceWarning:
# The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# c:\python27\lib\site-packages\arch\univariate\base.py:524: ConvergenceWarning:
# The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# c:\python27\lib\site-packages\arch\univariate\base.py:524: ConvergenceWarning:
# The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# ...

# %%
print correct_count
print total_count
# Out:
# 23
# 34

# %%
len(buy_list[:])
# Out:
# 34

# %%
buy_list[-1]
# Out:
# '603260.XSHG'

# %%
correct_count
# Out:
# 30

# %%
import auquanToolbox.dataloader as dl
from pandas.tseries.offsets import BDay

# 读取数据
data = pd.read_csv("price_data.csv",index_col  = 0)

# log returns
# lrets = np.log(data/data.shift(1)).dropna() 

lrets = data.pct_change().dropna()

# %%
type(lrets)
lrets
# Out:
# 2016-07-27    0.002591
# 2016-07-28    0.041344
# 2016-07-29    0.004963
# 2016-08-01   -0.014815
# 2016-08-02    0.025063
# 2016-08-03    0.044010
# 2016-08-04    0.000000
# 2016-08-05   -0.007026
# 2016-08-08    0.007075
# 2016-08-09   -0.014052
# 2016-08-10    0.000000
# 2016-08-11   -0.004751
# 2016-08-12   -0.014320
# 2016-08-15    0.024213
# 2016-08-16    0.002364
# 2016-08-17   -0.011792
# 2016-08-18   -0.014320
# 2016-08-19    0.009685
# 2016-08-22   -0.021583
# 2016-08-23    0.004902
# 2016-08-24    0.002439
# 2016-08-25    0.000000
# 2016-08-26   -0.002433
# 2016-08-29    0.004878
# 2016-08-30   -0.004854
# 2016-08-31    0.000000
# 2016-09-01   -0.012195
# 2016-09-02   -0.017284
# 2016-09-05    0.030151
# 2016-09-06    0.024390
#                 ...
# 2018-07-02   -0.020000
# 2018-07-03   -0.015606
# 2018-07-04   -0.039024
# 2018-07-05   -0.021574
# 2018-07-06    0.027237
# 2018-07-09    0.013889
# 2018-07-10    0.026152
# 2018-07-11    0.004854
# 2018-07-12   -0.002415
# ...

# %%
def tsplot(y, lags=None, figsize=(15, 10), style='bmh'):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        #mpl.rcParams['font.family'] = 'Ubuntu Mono'
        layout = (3, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        qq_ax = plt.subplot2grid(layout, (2, 0))
        pp_ax = plt.subplot2grid(layout, (2, 1))
        
        y.plot(ax=ts_ax)
        ts_ax.set_title('Time Series Analysis Plots')
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.05)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.05)
        sm.qqplot(y, line='s', ax=qq_ax)
        qq_ax.set_title('QQ Plot')        
        scs.probplot(y, sparams=(y.mean(), y.std()), plot=pp_ax)

        plt.tight_layout()
    return

# %%
def _get_best_model(TS):
    best_aic = np.inf 
    best_order = None
    best_mdl = None

    pq_rng = range(5) # [0,1,2,3,4]
    d_rng = range(2) # [0,1]
    for i in pq_rng:
        for d in d_rng:
            for j in pq_rng:
                try:
                    tmp_mdl = smt.ARIMA(TS, order=(i,d,j)).fit(
                        method='mle', trend='nc'
                    )
                    tmp_aic = tmp_mdl.aic
                    if tmp_aic < best_aic:
                        best_aic = tmp_aic
                        best_order = (i, d, j)
                        best_mdl = tmp_mdl
                except: continue
    print('aic: {:6.5f} | order: {}'.format(best_aic, best_order))                    
    return best_aic, best_order, best_mdl

# %%
# Notice I've selected a specific time period to run this analysis
TS = lrets
# res_tup = _get_best_model(TS)

# order = res_tup[1]
# model = res_tup[2]

# %%
# Now we can fit the arch model using the best fit arima model parameters
# p_ = order[0]
# o_ = order[1]
# q_ = order[2]

p_ = 3
o_ = 0
q_ = 2

# Using student T distribution usually provides better fit
am = arch_model(TS, p=p_, o=o_, q=q_, dist='StudentsT')
res = am.fit(update_freq=5, disp='off')
print(res.summary())
# Out:
#                         Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                  000338.XSHE   R-squared:                      -0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                 -0.000
# Vol Model:                            GARCH   Log-Likelihood:                1274.89
# Distribution:      Standardized Student's t   AIC:                          -2533.77
# Method:                  Maximum Likelihood   BIC:                          -2500.07
#                                               No. Observations:                  499
# Date:                      Sun, Aug 19 2018   Df Residuals:                      491
# Time:                              22:25:17   Df Model:                            8
#                                   Mean Model
# ...
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# ...

# %%
tsplot(res.resid, lags=30)

# %%
out = res.forecast(horizon=1, start=None, align='origin')
print(out.mean.iloc[-1,:])
print(out.variance.iloc[-1,:])
# Out:
# h.1    0.001429
# h.2    0.001429
# h.3    0.001429
# Name: 2018-08-10, dtype: float64
# h.1    0.000449
# h.2    0.000443
# h.3    0.000434
# Name: 2018-08-10, dtype: float64

# %%
print out
