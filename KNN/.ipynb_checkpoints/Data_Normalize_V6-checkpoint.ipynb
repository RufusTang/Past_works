# %%
from __future__ import division      #除数可以显示为float

from six import StringIO    #使用聚宽readfile函数
import numpy as np
import pandas as pd
import time                 #使用time stamp
import datetime             
import matplotlib.pyplot as plt
import math



# 定义分组函数，对输入的数列按照n组进行划分
def get_group(sample_data):
    # 返回结果的数组
    ret_group = []
    if len(sample_data)!=0:
        # 确定最大值、最小值
        # 同时gap适当扩大，避免出现n+1的分组
        d_mean = np.mean(sample_data)
        d_std = np.std(sample_data)
        ret_group = [math.floor(vals) if abs(math.floor(vals)) <=3 else 4*abs(math.floor(vals))/math.floor(vals) for vals in (np.array(sample_data) - d_mean)/(0.5*d_std)]
    else:
        ret_group =  []
    return ret_group

# 特征向量
Col_Name = ['EMA_5', 'EMA_10', 'EMA_gap', 'KDJ_K', 'KDJ_D', 'KDJ_J', 'RSI', 'MACD_dif', 'MACD_dea', 'MACD_macd',
                'MOM_12', 'MOM_25', 'MOM_gap', 'OBV', 'Long_Short_Rate_OBV', 'Volume']

# 生成总的列表
Col_Total = []
for col in Col_Name:
    Col_Total.append(col)
    
    # 生成前两天的值
    for day_count_i in range(1, 3):
        Col_Total.append(str(str(col) + "_pre" + str(day_count_i)))

# %%
# 均方差列表
MS_List_pd = pd.DataFrame()

# 开始处理文件
for file_i in range(1,2,1):
    Data_Total = pd.DataFrame()

    file_name = "raw_data%d.csv" % (int(file_i))
    Data_Total = pd.read_csv(file_name)

    print "开始处理文件：%s" % str(file_name)

    Stock_list = set(list(Data_Total['code']))



    #############################################  1、 增加一个前1-2天的值      ############################################################
    for col in Col_Name:
        print "步骤1：开始处理：%s" % str(col)
        
        # 修改列属性为float,之后数据透视需要
        Data_Total[col] = Data_Total[col].astype(float)
        for day_count_i in range(1, 3):

            Data_Total.loc[:, str(str(col) + "_pre" + str(day_count_i))] = None
            # 修改列属性为float,之后数据透视需要
            Data_Total[str(str(col) + "_pre" + str(day_count_i))] = Data_Total[str(str(col) + "_pre" + str(day_count_i))].astype(float)
            for stock_name in Stock_list:
                temp = []
                temp = list(Data_Total.loc[Data_Total['code'] == stock_name, "MACD_macd"])[day_count_i:]
                for i in range(0, day_count_i):
                    temp.append(0)
                Data_Total.loc[Data_Total['code'] == stock_name, str(str(col) + "_pre" + str(day_count_i))] = np.array(temp)

    print "完成步骤1"

    #############################################  2、 删除无效数据，更改数据类型      ############################################################
    # 更改平局为-1
    Data_Total.loc[Data_Total['win_rate'] == 0, "win_rate"] = -1

    # 删除前60，后10的数据
    for stock_name in Stock_list:
        Data_Total = Data_Total.drop(Data_Total[Data_Total['code'] == stock_name].iloc[:60].index, axis=0)
        Data_Total = Data_Total.drop(Data_Total[Data_Total['code'] == stock_name].iloc[-10:].index, axis=0)

    # 统一操作，删除价格为0的数据
    Data_Total = Data_Total.drop(Data_Total[Data_Total['price'] == 0].index, axis=0)

    print "完成步骤2"

    #############################################  3、 归一化数据      ############################################################
    Data_Normalize = pd.DataFrame()

    # 赋值列：code、date，avg_price，win_rate
    Data_Normalize = Data_Total.loc[:, ['code', 'date', 'price', 'win_rate']]

    for col in Col_Name:
        print "步骤3：开始处理：%s" % str(col)

        # 处理原始列数据
        Data_Normalize.loc[:, col] = None

        for stock_name in Stock_list:
            Data_Normalize.loc[Data_Normalize['code'] == stock_name, col] \
                = np.array(get_group(list(Data_Total[Data_Total['code'] == stock_name][col])))

        # 处理扩展的列数据
        for day_count_i in range(1, 3):
            Data_Normalize.loc[:, str(str(col) + "_pre" + str(day_count_i))] = None


            for stock_name in Stock_list:
                Data_Normalize.loc[Data_Normalize['code'] == stock_name, str(str(col) + "_pre" + str(day_count_i))] \
                    = np.array(get_group(
                    list(Data_Total[Data_Total['code'] == stock_name][str(str(col) + "_pre" + str(day_count_i))])))

    print "完成步骤3"
    #############################################  4、生成文件     ############################################################

    file_name_normalize = 'Data_Washed%d.csv' % (int(file_i))
    Data_Normalize.to_csv(file_name_normalize)
    
    
    #############################################  5、生成均方差列表    ############################################################
    print "生成均方差列表"
    MS_List_pd = pd.concat([MS_List_pd, pd.pivot_table(Data_Total,index=["code"],values=Col_Total,aggfunc=[np.mean,np.std])])

    
##############################################  6、打印保存均方差列表    ############################################################
print '打印均方差列表'
MS_List_pd.to_csv("MS_List.csv")
# Out:
# 开始处理文件：raw_data1.csv
# 步骤1：开始处理：EMA_5
# 步骤1：开始处理：EMA_10
# 步骤1：开始处理：EMA_gap
# 步骤1：开始处理：KDJ_K
# 步骤1：开始处理：KDJ_D
# 步骤1：开始处理：KDJ_J
# 步骤1：开始处理：RSI
# 步骤1：开始处理：MACD_dif
# 步骤1：开始处理：MACD_dea
# 步骤1：开始处理：MACD_macd
# 步骤1：开始处理：MOM_12
# 步骤1：开始处理：MOM_25
# 步骤1：开始处理：MOM_gap
# 步骤1：开始处理：OBV
# 步骤1：开始处理：Long_Short_Rate_OBV
# 步骤1：开始处理：Volume
# 完成步骤1
# 完成步骤2
# 步骤3：开始处理：EMA_5
# 步骤3：开始处理：EMA_10
# 步骤3：开始处理：EMA_gap
# 步骤3：开始处理：KDJ_K
# 步骤3：开始处理：KDJ_D
# 步骤3：开始处理：KDJ_J
# 步骤3：开始处理：RSI
# 步骤3：开始处理：MACD_dif
# 步骤3：开始处理：MACD_dea
# 步骤3：开始处理：MACD_macd
# 步骤3：开始处理：MOM_12
# 步骤3：开始处理：MOM_25
# 步骤3：开始处理：MOM_gap
# 步骤3：开始处理：OBV
# 步骤3：开始处理：Long_Short_Rate_OBV
# 步骤3：开始处理：Volume
# 完成步骤3
#                   mean                                                       \
#                 EMA_10   EMA_10_pre1   EMA_10_pre2      EMA_5    EMA_5_pre1
# code
# 000001.XSHE  13.508782  3.736394e-04  4.395511e-04  13.496854  3.736394e-04
# 000002.XSHE  14.150790  5.295212e-05 -8.605792e-05  14.182276  5.295212e-05
# 000060.XSHE  11.231440  1.736048e-03  2.292544e-03  11.211949  1.736048e-03
# 000063.XSHE  18.987615  1.251979e-03  1.480893e-03  18.975295  1.251979e-03
# 000069.XSHE   7.819899  3.013661e-04  3.017653e-04   7.814124  3.013661e-04
# 000651.XSHE  12.525629  0.237945  0.237936  4.570906e+07    0.237945
# 000671.XSHE  14.166003  0.111232  0.110417  2.023615e+07    0.111232
# 000709.XSHE  14.249038  0.023211  0.023208  1.559914e+08    0.023211
# 000723.XSHE  16.063208  0.108996  0.108993  9.107985e+06    0.108996
# 000725.XSHE  12.519238  0.018653  0.018654  4.656912e+08    0.018653
# 000728.XSHE  13.355894  0.125619  0.125623  2.899255e+07    0.125619
#
#
#             Volume_pre2
# code
# 000001.XSHE    0.079137
# 000002.XSHE    0.095135
# 000060.XSHE    0.108696
# 000063.XSHE    0.138916
# 000069.XSHE    0.059241
# 000100.XSHE    0.027022
# 000157.XSHE    0.090191
# 000166.XSHE    0.111346
# 000333.XSHE    0.338440
# 000338.XSHE    0.421290
# 000402.XSHE    0.052462
# 000413.XSHE    0.109551
# 000415.XSHE    0.094344
# 000423.XSHE    0.213197
# 000425.XSHE    0.206709
# 000503.XSHE    0.248947
# 000538.XSHE    0.334667
# 000540.XSHE    0.127770
# 000559.XSHE    0.120116
# 000568.XSHE    0.178940
# 000623.XSHE    0.171080
# 000625.XSHE    0.072573
# 000627.XSHE    0.056315
# 000630.XSHE    0.113021
# 000651.XSHE    0.237936
# 000671.XSHE    0.110417
# 000709.XSHE    0.023208
# 000723.XSHE    0.108993
# 000725.XSHE    0.018654
# 000728.XSHE    0.125623
#
# [30 rows x 96 columns]

# %%
Col_Total
# pd.pivot_table(Data_Total,index=["code"],values=['Volume_pre1','Volume_pre2'],aggfunc=[np.mean,np.std])
# # Data_Total
Data_Total.dtypes
# Out:
# Unnamed: 0                    int64
# code                         object
# date                         object
# price                       float64
# win_rate                      int64
# MACD_dif                    float64
# MACD_dea                    float64
# MACD_macd                   float64
# EMA_5                       float64
# EMA_10                      float64
# EMA_gap                     float64
# KDJ_K                       float64
# KDJ_D                       float64
# KDJ_J                       float64
# RSI                         float64
# MOM_12                      float64
# MOM_25                      float64
# MOM_gap                     float64
# OBV                         float64
# Long_Short_Rate_OBV         float64
# Volume                      float64
# EMA_5_pre1                  float64
# EMA_5_pre2                  float64
# EMA_10_pre1                 float64
# EMA_10_pre2                 float64
# EMA_gap_pre1                float64
# EMA_gap_pre2                float64
# KDJ_K_pre1                  float64
# KDJ_K_pre2                  float64
# KDJ_D_pre1                  float64
# KDJ_D_pre2                  float64
# KDJ_J_pre1                  float64
# KDJ_J_pre2                  float64
# RSI_pre1                    float64
# RSI_pre2                    float64
# MACD_dif_pre1               float64
# MACD_dif_pre2               float64
# MACD_dea_pre1               float64
# MACD_dea_pre2               float64
# MACD_macd_pre1              float64
# MACD_macd_pre2              float64
# MOM_12_pre1                 float64
# MOM_12_pre2                 float64
# MOM_25_pre1                 float64
# MOM_25_pre2                 float64
# MOM_gap_pre1                float64
# MOM_gap_pre2                float64
# OBV_pre1                    float64
# OBV_pre2                    float64
# Long_Short_Rate_OBV_pre1    float64
# Long_Short_Rate_OBV_pre2    float64
# Volume_pre1                 float64
# Volume_pre2                 float64
# dtype: object
